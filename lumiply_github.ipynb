# %% [markdown]
# ## gitignore:
# #### 아래 파일들 허깅페이스에서 다운 받기
# - ckpt/trained_crossattn.ckpt  (7575.69 MB)
# - ckpt/new_decoder.ckpt  (801.58 MB)
# - ckpt/last.pth.tar  (1487.45 MB)
# - ckpt/LumiNet.ckpt  (14124.30 MB)
# - adaptors/adaptor_green.pth  (161.08 MB)
# - adaptors/adaptor_blue.pth  (161.08 MB)
# - adaptors/adaptor_purple.pth  (161.08 MB)
# - adaptors/adaptor_orange.pth  (161.08 MB)
# - adaptors/adaptor_red.pth  (161.08 MB)
# - adaptors/adaptor_yellow.pth  (161.08 MB)

# %%
# %cd /content/drive/MyDrive/LumiNet_Files/lumiply-colab
# !pwd
# Out:
# /content/drive/MyDrive/LumiNet_Files/lumiply-colab
# /content/drive/MyDrive/LumiNet_Files/lumiply-colab

# %%
# !ls
# Out:
# 23_off.jpeg	       images			    modi_vae
# adaptors	       ldm			    README.md
# ckpt		       Load_model.py		    relit_inference.py
# cldm		       lumiply_github.ipynb	    requirements.txt
# crossattn_checkpoints  lumiply_inference.ipynb	    seed_selection.py
# flux_cleanup.py        lumiply_ready_for_git.ipynb  Untitled0.ipynb
# font		       Lumiply_test.ipynb
# gradio_demo.py	       models

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/LumiNet_Files/lumiply-colab/.git/

# %%
# !git config --global user.email "lyj72011648@gmail.com"
# !git config --global user.name "EthanYJLee"

# %%
# !git remote -v

# %%
# !git remote set-url origin https://github.com/EthanYJLee/lumiply-colab.git
# !git remote -v

# %%
# !git add .

# %%
# !git status
# Out:
# Refresh index: 100% (799/799), done.
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	modified:   .gitignore
# 	new file:   adaptors/.gitkeep
# 	modified:   lumiply_github.ipynb

# %%
# !git commit -m "feat: update gitignore"
# !git branch -M main
# Out:
# [main a3f3277] feat: update gitignore
#  3 files changed, 4 insertions(+), 3 deletions(-)
#  create mode 100644 adaptors/.gitkeep
#  rewrite lumiply_github.ipynb (99%)

# %%
# !git remote set-url origin https://github.com/EthanYJLee/lumiply-colab.git

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/EthanYJLee/lumiply-colab.git (fetch)
# origin	https://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@github.com/EthanYJLee/lumiply-colab.git (push)

# %%
username = "EthanYJLee"
repo     = "lumiply-colab"
# token    = "github_access_token"

remote_url = f"https://{token}@github.com/{username}/{repo}.git"
print(remote_url)
# Out:
# https://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@github.com/EthanYJLee/lumiply-colab.git

# %%
# !git remote set-url origin "$remote_url"
# !git remote -v
# Out:
# origin	https://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@github.com/EthanYJLee/lumiply-colab.git (fetch)
# origin	https://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@github.com/EthanYJLee/lumiply-colab.git (push)

# %%
# !git push -u origin main
# Out:
# fatal: could not read Password for 'https://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@github.com': No such device or address

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/EthanYJLee/lumiply-colab.git (fetch)
# origin	https://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@github.com/EthanYJLee/lumiply-colab.git (push)

# %%
# !git remote set-url origin https://github.com/EthanYJLee/lumiply-colab.git
# !git remote -v
# Out:
# origin	https://github.com/EthanYJLee/lumiply-colab.git (fetch)
# origin	https://github.com/EthanYJLee/lumiply-colab.git (push)

# %%
USERNAME = "EthanYJLee"
TOKEN = "github access token"

REPO = "lumiply-colab"

# !git push https://{USERNAME}:{TOKEN}@github.com/{USERNAME}/{REPO}.git main
# Out:
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 12 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 31.60 KiB | 2.26 MiB/s, done.
# Total 5 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/EthanYJLee/lumiply-colab.git
#    bee75ed..e03727d  main -> main
